# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

sample_path= './archive/brisc2025/classification_task/train/glioma/brisc2025_train_00001_gl_ax_t1.jpg'
img = cv2.imread(sample_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

#data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.1,
    zoom_range=0.2,
    brightness_range=[0.7, 1.3],
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
    )

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    './archive/brisc2025/classification_task/train',
    target_size=(256, 256),
    color_mode='grayscale',
    batch_size=32,
    class_mode='categorical',
    shuffle = True
)
test_generator = test_datagen.flow_from_directory(
    './archive/brisc2025/classification_task/test',
    target_size=(256, 256),
    color_mode='grayscale',
    batch_size=32,
    class_mode='categorical',
    shuffle = False
)

early_stop = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, min_lr=1e-6)

model = models.Sequential([
    layers.Input(shape=(256,256,1)),
    
    # Block1
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.1),
    
    # Block2
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.15),
    
    # Block3
    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.2),
    
    # Block4
    layers.Conv2D(256,(3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),
    
    layers.GlobalAveragePooling2D(),
    
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),

    layers.Dropout(0.3),
    
    layers.Dense(4, activation ='softmax')
])
optimizer = Adam(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy'],
    )


model.summary()

history= model.fit(
    train_generator,
    epochs=100,
    validation_data=test_generator,
    callbacks=[early_stop, reduce_lr]

)
# Out:
# Found 5000 images belonging to 4 classes.
# Found 1000 images belonging to 4 classes.
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)                   │ (None, 256, 256, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_20               │ (None, 256, 256, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_20 (MaxPooling2D)      │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_25 (Dropout)                 │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 128, 128, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_21               │ (None, 128, 128, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_21 (MaxPooling2D)      │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 64, 64, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_22               │ (None, 64, 64, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_22 (MaxPooling2D)      │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_27 (Dropout)                 │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 32, 32, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_23               │ (None, 32, 32, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_23 (MaxPooling2D)      │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_28 (Dropout)                 │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_5           │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_29 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 456,580 (1.74 MB)
#  Trainable params: 455,620 (1.74 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 233s 1s/step - accuracy: 0.5974 - loss: 1.1983 - val_accuracy: 0.3000 - val_loss: 2.9245 - learning_rate: 0.0010
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - accuracy: 0.7392 - loss: 0.8489 - val_accuracy: 0.3010 - val_loss: 4.6233 - learning_rate: 0.0010
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - accuracy: 0.7890 - loss: 0.7002 - val_accuracy: 0.3150 - val_loss: 6.7704 - learning_rate: 0.0010
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.8210 - loss: 0.6109 - val_accuracy: 0.4830 - val_loss: 2.2947 - learning_rate: 0.0010
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.8300 - loss: 0.5813 - val_accuracy: 0.3260 - val_loss: 7.1441 - learning_rate: 0.0010
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.8538 - loss: 0.5015 - val_accuracy: 0.4180 - val_loss: 5.7979 - learning_rate: 0.0010
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.8540 - loss: 0.4848 - val_accuracy: 0.6020 - val_loss: 1.5357 - learning_rate: 0.0010
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.8638 - loss: 0.4533 - val_accuracy: 0.3000 - val_loss: 15.6350 - learning_rate: 0.0010
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.8722 - loss: 0.4201 - val_accuracy: 0.4060 - val_loss: 4.7096 - learning_rate: 0.0010
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.8704 - loss: 0.4161 - val_accuracy: 0.3060 - val_loss: 3.5548 - learning_rate: 0.0010
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.8772 - loss: 0.3945 - val_accuracy: 0.4260 - val_loss: 3.0823 - learning_rate: 0.0010
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.8824 - loss: 0.3796 - val_accuracy: 0.6300 - val_loss: 2.0664 - learning_rate: 0.0010
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 221s 1s/step - accuracy: 0.8822 - loss: 0.3631 - val_accuracy: 0.3370 - val_loss: 7.0444 - learning_rate: 0.0010
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.8932 - loss: 0.3479 - val_accuracy: 0.5930 - val_loss: 1.7123 - learning_rate: 0.0010
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.8900 - loss: 0.3376 - val_accuracy: 0.4340 - val_loss: 2.7466 - learning_rate: 0.0010
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.8942 - loss: 0.3189 - val_accuracy: 0.6340 - val_loss: 1.2112 - learning_rate: 0.0010
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.9030 - loss: 0.3000 - val_accuracy: 0.6370 - val_loss: 1.1607 - learning_rate: 0.0010
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.9044 - loss: 0.3056 - val_accuracy: 0.7300 - val_loss: 0.9953 - learning_rate: 0.0010
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - accuracy: 0.9168 - loss: 0.2750 - val_accuracy: 0.3710 - val_loss: 3.6517 - learning_rate: 0.0010
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 221s 1s/step - accuracy: 0.9202 - loss: 0.2751 - val_accuracy: 0.6520 - val_loss: 1.0808 - learning_rate: 0.0010
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9258 - loss: 0.2418 - val_accuracy: 0.8080 - val_loss: 0.5805 - learning_rate: 0.0010
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9250 - loss: 0.2495 - val_accuracy: 0.3640 - val_loss: 2.9665 - learning_rate: 0.0010
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9246 - loss: 0.2460 - val_accuracy: 0.7200 - val_loss: 0.7548 - learning_rate: 0.0010
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9252 - loss: 0.2420 - val_accuracy: 0.8370 - val_loss: 0.4640 - learning_rate: 0.0010
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9312 - loss: 0.2261 - val_accuracy: 0.4500 - val_loss: 2.6973 - learning_rate: 0.0010
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9354 - loss: 0.2200 - val_accuracy: 0.7560 - val_loss: 0.6935 - learning_rate: 0.0010
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9396 - loss: 0.2064 - val_accuracy: 0.8490 - val_loss: 0.4566 - learning_rate: 0.0010
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9410 - loss: 0.1996 - val_accuracy: 0.7240 - val_loss: 0.8725 - learning_rate: 0.0010
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9370 - loss: 0.2129 - val_accuracy: 0.7160 - val_loss: 0.8795 - learning_rate: 0.0010
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9344 - loss: 0.2171 - val_accuracy: 0.7940 - val_loss: 0.7220 - learning_rate: 0.0010
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9406 - loss: 0.1952 - val_accuracy: 0.4520 - val_loss: 3.1651 - learning_rate: 0.0010
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9442 - loss: 0.1881 - val_accuracy: 0.2790 - val_loss: 4.0743 - learning_rate: 0.0010
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9512 - loss: 0.1707 - val_accuracy: 0.9040 - val_loss: 0.3312 - learning_rate: 5.0000e-04
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9580 - loss: 0.1498 - val_accuracy: 0.9070 - val_loss: 0.2905 - learning_rate: 5.0000e-04
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9572 - loss: 0.1531 - val_accuracy: 0.9120 - val_loss: 0.2452 - learning_rate: 5.0000e-04
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9594 - loss: 0.1485 - val_accuracy: 0.9330 - val_loss: 0.2003 - learning_rate: 5.0000e-04
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9622 - loss: 0.1389 - val_accuracy: 0.8890 - val_loss: 0.3309 - learning_rate: 5.0000e-04
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - accuracy: 0.9606 - loss: 0.1441 - val_accuracy: 0.8330 - val_loss: 0.6082 - learning_rate: 5.0000e-04
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9618 - loss: 0.1430 - val_accuracy: 0.9230 - val_loss: 0.2384 - learning_rate: 5.0000e-04
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9642 - loss: 0.1323 - val_accuracy: 0.8650 - val_loss: 0.5052 - learning_rate: 5.0000e-04
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9588 - loss: 0.1351 - val_accuracy: 0.8600 - val_loss: 0.4779 - learning_rate: 5.0000e-04
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9704 - loss: 0.1206 - val_accuracy: 0.8650 - val_loss: 0.4256 - learning_rate: 2.5000e-04
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - accuracy: 0.9698 - loss: 0.1197 - val_accuracy: 0.8300 - val_loss: 0.5449 - learning_rate: 2.5000e-04
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9730 - loss: 0.1116 - val_accuracy: 0.9600 - val_loss: 0.1405 - learning_rate: 2.5000e-04
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9686 - loss: 0.1158 - val_accuracy: 0.8400 - val_loss: 0.4737 - learning_rate: 2.5000e-04
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9742 - loss: 0.1060 - val_accuracy: 0.8340 - val_loss: 0.6639 - learning_rate: 2.5000e-04
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9696 - loss: 0.1092 - val_accuracy: 0.9200 - val_loss: 0.2287 - learning_rate: 2.5000e-04
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9676 - loss: 0.1100 - val_accuracy: 0.9620 - val_loss: 0.1332 - learning_rate: 2.5000e-04
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9726 - loss: 0.1032 - val_accuracy: 0.7520 - val_loss: 0.9043 - learning_rate: 2.5000e-04
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9732 - loss: 0.1084 - val_accuracy: 0.9090 - val_loss: 0.2982 - learning_rate: 2.5000e-04
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9746 - loss: 0.0992 - val_accuracy: 0.8990 - val_loss: 0.3424 - learning_rate: 2.5000e-04
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9730 - loss: 0.1041 - val_accuracy: 0.9140 - val_loss: 0.2947 - learning_rate: 2.5000e-04
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9748 - loss: 0.0988 - val_accuracy: 0.8130 - val_loss: 0.6334 - learning_rate: 2.5000e-04
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9762 - loss: 0.0936 - val_accuracy: 0.9100 - val_loss: 0.2698 - learning_rate: 1.2500e-04
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9768 - loss: 0.0951 - val_accuracy: 0.9640 - val_loss: 0.1431 - learning_rate: 1.2500e-04
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - accuracy: 0.9740 - loss: 0.1013 - val_accuracy: 0.8590 - val_loss: 0.4468 - learning_rate: 1.2500e-04
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - accuracy: 0.9764 - loss: 0.0898 - val_accuracy: 0.8560 - val_loss: 0.4624 - learning_rate: 1.2500e-04
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9792 - loss: 0.0873 - val_accuracy: 0.9260 - val_loss: 0.2252 - learning_rate: 1.2500e-04
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - accuracy: 0.9782 - loss: 0.0902 - val_accuracy: 0.9390 - val_loss: 0.1891 - learning_rate: 1.2500e-04
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - accuracy: 0.9782 - loss: 0.0879 - val_accuracy: 0.8600 - val_loss: 0.4069 - learning_rate: 1.2500e-04
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - accuracy: 0.9778 - loss: 0.0914 - val_accuracy: 0.9190 - val_loss: 0.2406 - learning_rate: 6.2500e-05
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - accuracy: 0.9792 - loss: 0.0870 - val_accuracy: 0.9560 - val_loss: 0.1603 - learning_rate: 6.2500e-05
# Epoch 63/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - accuracy: 0.9808 - loss: 0.0822 - val_accuracy: 0.9310 - val_loss: 0.2245 - learning_rate: 6.2500e-05
# Epoch 64/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - accuracy: 0.9834 - loss: 0.0780 - val_accuracy: 0.9750 - val_loss: 0.1194 - learning_rate: 6.2500e-05
# Epoch 65/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - accuracy: 0.9824 - loss: 0.0806 - val_accuracy: 0.9270 - val_loss: 0.2235 - learning_rate: 6.2500e-05
# Epoch 66/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.9824 - loss: 0.0820 - val_accuracy: 0.9630 - val_loss: 0.1334 - learning_rate: 6.2500e-05
# Epoch 67/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - accuracy: 0.9822 - loss: 0.0795 - val_accuracy: 0.9710 - val_loss: 0.1166 - learning_rate: 6.2500e-05
# Epoch 68/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - accuracy: 0.9818 - loss: 0.0803 - val_accuracy: 0.9440 - val_loss: 0.1810 - learning_rate: 6.2500e-05
# Epoch 69/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - accuracy: 0.9812 - loss: 0.0775 - val_accuracy: 0.9560 - val_loss: 0.1678 - learning_rate: 6.2500e-05
# Epoch 70/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - accuracy: 0.9824 - loss: 0.0792 - val_accuracy: 0.9450 - val_loss: 0.1934 - learning_rate: 3.1250e-05
# Epoch 71/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - accuracy: 0.9802 - loss: 0.0828 - val_accuracy: 0.9700 - val_loss: 0.1235 - learning_rate: 3.1250e-05
# Epoch 72/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 228s 1s/step - accuracy: 0.9810 - loss: 0.0805 - val_accuracy: 0.9490 - val_loss: 0.1737 - learning_rate: 3.1250e-05
# Epoch 73/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9820 - loss: 0.0762 - val_accuracy: 0.9370 - val_loss: 0.1949 - learning_rate: 3.1250e-05
# Epoch 74/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 251s 2s/step - accuracy: 0.9832 - loss: 0.0793 - val_accuracy: 0.9470 - val_loss: 0.1792 - learning_rate: 3.1250e-05

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Train vs Validation Accuracy')
plt.legend()

# Loss plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss')
plt.legend()

plt.show()

# %%
import numpy as np

# Predict probabilities
y_pred_probs = model.predict(test_generator)

# Convert to class indices
y_pred = np.argmax(y_pred_probs, axis=1)

# True labels
y_true = test_generator.classes
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 389ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print(f'Test Accuracy: {accuracy*100:.2f}%')
print(f'Test Precision: {precision*100:.2f}%')
print(f'Test Recall: {recall*100:.2f}%')
print(f'Test F1 Score: {f1*100:.2f}%')

# Detailed per-class report
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_generator.class_indices.keys())))
# Out:
# Test Accuracy: 97.50%
# Test Precision: 97.55%
# Test Recall: 97.50%
# Test F1 Score: 97.49%
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       glioma       0.99      0.93      0.96       254
#   meningioma       0.94      0.98      0.96       306
#     no_tumor       0.99      1.00      1.00       140
#    pituitary       0.99      1.00      0.99       300
#
#     accuracy                           0.97      1000
#    macro avg       0.98      0.98      0.98      1000
# weighted avg       0.98      0.97      0.97      1000

# %%
import matplotlib

print(matplotlib.__version__)

import matplotlib.pyplot as plt
import numpy as np

# x=np.array([0,6,6,0])
# y=np.array([6,250,6,0]) 

# plt.plot(x,y)

x=np.array([0,10,2,30,0,50,6,70,8,90,1])
plt.plot(x)
plt.plot(x,'o')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# line style - : (dotted), --(dashed), -(solid), -. (dash dot)
# r,g,b,c,m,y,k,w - different colors
# marker - o,*,.,p, etc
# ms- marker size, mew - marker edge width, mec - marker edge color, mfc - marker face color

x=np.array([0,6,3,9])
y=np.array([0,3,6,9])
# plt.plot(x,marker='p',ms=20)  # marker size
# plt.plot(x,marker='o')
# plt.plot(x, 'o:r')
# plt.plot(x, 'o-g') 
# plt.plot(x, 'o--b')
# plt.plot(x, 'o-.c')
# plt.plot(x, 'o-.m')
# plt.plot(x, 'o-.y')
# plt.plot(x, 'o-.k')
# plt.plot(x, 'o-.w')
# plt.plot(x, linestyle=':')
# plt.plot(x, ls=':', color='c')
# plt.plot(x, lw=5)  # line width

# plt.plot(x)
# plt.plot(y)

# %%
import matplotlib.pyplot as plt
import numpy as np

font1 = {'family':'serif','color':'blue','size':20}
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1,y1,x2,y2) 
# plt.title("Line graph" ,fontdict=font1, loc='left') # loc - left, right, center
# plt.xlabel("X axis")
# plt.ylabel("Y axis")

# plt.grid(axis='x') # axis - x, y, both
# plt.grid(axis='y')

# plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.subplot(1,2,1) # (rows, columns, position)
#rows - no of rows in the graph
#columns - no of columns in the graph
#position - position of the graph
plt.plot(x1,y1)
plt.suptitle("Graph " )


plt.title("Graph 1" ) 
plt.plot(x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)
plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np  

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

# plt.scatter(x,y,color="red")

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,c=colors)

plt.show()

# %%
#Bars
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A","B","C","D"])
y = np.array([3,8,1,10])
# plt.bar(x,y)
# plt.barh(x,y)
# plt.bar(x,y,color='red')
plt.barh(x,y,color="red",height=0.2)
plt.show()

# %%
#histogram
import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y= np.array(["35","20","49","20"])
myLabels= ["A","B","C","D"]
# plt.pie(y)
# plt.pie(y,labels=myLabels)
plt.pie(y,labels=myLabels,startangle=90) 
plt.show()

# %%
#image show
import matplotlib.pyplot as plt
import numpy as np
img = plt.imread("./flower.jpg")
plt.imshow(img)
plt.axis('off') # to hide axis
# Out:
# (np.float64(-0.5), np.float64(5183.5), np.float64(3455.5), np.float64(-0.5))
